# %% [markdown]
# # ACLUm BPD Open Checkbook Surveillance Project

# %% [markdown]
# We aim to cross-reference BPD's Open Checkbook data against the Surveillance Industry Index.
#
# You can download the data yourself here:
#
# ```
# $ wget -O ledger.csv https://spending.data.boston.gov/api/ledger.csv
# $ wget -O sii.html https://sii.transparencytoolkit.org/
# ```

# %% [markdown]
# ### Get the list of surveillance companies
#
# SII doesn't have an API that just grabs the list so we'll regex out the list in the sidebar from the HTML. There are exactly 500 of them, which is a _bit_ suspicious.

# %%
import re
import itertools
import urllib
pattern = re.compile(r"company_name_facet=(.*?)&amp")

with open('sii.html', 'r') as sii:
    messy = itertools.chain.from_iterable(map(lambda line: re.findall(pattern, line), sii))
    surveillance_companies = list(map(lambda s: urllib.unquote_plus(s), messy))

# %% [markdown]
# ### Get the list of BPD vendors

# %%
import pandas
ledger = pandas.read_csv("ledger.csv")
#list(ledger)
# Out:
# /usr/lib/python2.7/dist-packages/pandas/io/parsers.py:1139: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = self._reader.read(nrows)

# %%
police = ledger.loc[ledger['dept_name'] == "Police Department"]
vendors = map(lambda s: s.lower(), police.vendor_name.unique())

# %% [markdown]
# A function to find the common overlap between two strings of text.

# %%
def longest_common_substring(s1, s2):
   m = [[0] * (1 + len(s2)) for i in xrange(1 + len(s1))]
   longest, x_longest = 0, 0
   for x in xrange(1, 1 + len(s1)):
       for y in xrange(1, 1 + len(s2)):
           if s1[x - 1] == s2[y - 1]:
               m[x][y] = m[x - 1][y - 1] + 1
               if m[x][y] > longest:
                   longest = m[x][y]
                   x_longest = x
           else:
               m[x][y] = 0
   return s1[x_longest - longest: x_longest]

# %% [markdown]
# ### Doing the comparison
#
# We'll compare every vendor in the list with the list of companies. if there's more than a 50% length match, we'll mark it as interesting. It turns out that a lot of these companies are called Something **Technologies** or Whatever **Systems** so we'll build a list of these words that can be ignored.

# %%
import string
stripwords = ["technologies", "technology",
              "system", "systems",
              "network", "networks",
              "communication", "communications", 
              "electronic", "electronics",
              "service", "services",
              "solution", "solutions",
              "forensic", "forensics",
              "consultant", "consultants",
              "international", "software", "corporation",  "group", "tactical", "security"]
def sanitize(word):
    nopunc = word.translate(None, string.punctuation)
    return " ".join(filter(lambda e: e not in stripwords, nopunc.split()))
vendor_data = map(lambda v: (v, sanitize(v)), vendors)
company_data = map(lambda c: (c, sanitize(c)), surveillance_companies)

# %%
matches = []
for (vendor, strip_vendor) in vendor_data:
    for (company, strip_company) in company_data:
        substr = longest_common_substring(strip_vendor, strip_company)
        if len(substr) > (max(len(strip_vendor), len(strip_company)) / 2):
            matches.append({"left": vendor, "right": company})

# %%
from csv import DictWriter
with open("surveillance.csv", 'w+') as surveillance:
    dw = DictWriter(surveillance, fieldnames=["left", "right"])
    dw.writeheader()
    for match in matches:
        dw.writerow(match)

# %% [markdown]
# ### Get the list of purchases from the listed vendors

# %%
surveilly_vendors = ["cellebrite usa,corp.", "federal signal corp.", "guidance software",
                     "harris corporation, gcsd", "northrop grumman information technology",
                     "northrop grumman systems corp.", "paraben corporation", "salient stills, inc.",
                     "geofeedia, inc.", "pen link ltd."]

police['vendor_lower'] = police.apply(lambda r: r.vendor_name.lower(), axis=1)
purchases = police[ (police.vendor_lower.isin(surveilly_vendors)) ]

# %%
purchases
# Out:
#          voucher  voucher_line  distribution_line                  entered  \
# 72365    1754758             1                  1  2012-06-01T00:00:00.000
# 72366    1754758             2                  1  2012-06-01T00:00:00.000
# 72369    1816977             2                  1  2012-12-17T00:00:00.000
# 72370    1816977             1                  1  2012-12-17T00:00:00.000
# 72372    1882690             1                  1  2013-05-23T00:00:00.000
# 72373    1882521             2                  1  2013-05-23T00:00:00.000
# 72374    1882521             1                  1  2013-05-23T00:00:00.000
# 72376    1953000             2                  1  2013-11-26T00:00:00.000
# 72377    1953000             1                  1  2013-11-26T00:00:00.000
# 72378    2001337             1                  1  2014-04-08T00:00:00.000
# 131990   1665322             1                  1  2011-09-13T00:00:00.000
# 131991   1665323             1                  1  2011-09-13T00:00:00.000
# 131992   1736591             1                  1  2012-04-09T00:00:00.000
# 131993   1763846             1                  1  2012-06-25T00:00:00.000
# 167638   1694438             1                  1  2011-12-06T00:00:00.000
# 167639   1835588             1                  1  2013-02-05T00:00:00.000
# 169904   1908060             1                  1  2013-07-25T00:00:00.000
# 169905   1907943             1                  1  2013-07-25T00:00:00.000
# 169906   1908060             1                  1  2013-07-25T00:00:00.000
# 169907   1907943             1                  1  2013-07-25T00:00:00.000
# 169908   1897453             1                  1  2013-06-26T00:00:00.000
# 169909   1897453             2                  1  2013-06-26T00:00:00.000
# 169910   2036621             2                  1  2014-07-08T00:00:00.000
# 169911   2036621             1                  1  2014-07-08T00:00:00.000
# 169912   2036622             7                  1  2014-07-08T00:00:00.000
# 169913   2036622             6                  1  2014-07-08T00:00:00.000
# 169914   2036622             5                  1  2014-07-08T00:00:00.000
# 169915   2036622             4                  1  2014-07-08T00:00:00.000
# 169916   2036622             3                  1  2014-07-08T00:00:00.000
# 169917   2036622             2                  1  2014-07-08T00:00:00.000
# ...          ...           ...                ...                      ...
# 589976   2192208             1                  1  2015-08-03T00:00:00.000
# 645010   2264082             1                  1  2016-01-26T00:00:00.000
# 701449   2325580             1                  1  2016-06-16T00:00:00.000
# 701450   2325581             1                  1  2016-06-16T00:00:00.000
# 725490   2347326             1                  1  2016-08-03T00:00:00.000
# 725491   2347326             2                  1  2016-08-03T00:00:00.000
# 725492   2347326             3                  1  2016-08-03T00:00:00.000
# 725493   2347326             4                  1  2016-08-03T00:00:00.000
# 725494   2347326             5                  1  2016-08-03T00:00:00.000
# 725495   2347326             6                  1  2016-08-03T00:00:00.000
# 725496   2347326             7                  1  2016-08-03T00:00:00.000
# 725497   2347326             8                  1  2016-08-03T00:00:00.000
# 725498   2347326             9                  1  2016-08-03T00:00:00.000
# 725499   2347326            10                  1  2016-08-03T00:00:00.000
# 725500   2347326            11                  1  2016-08-03T00:00:00.000
# 725501   2347326            12                  1  2016-08-03T00:00:00.000
# 725503  211100  Police Department  Police Commissioner's Office
# 725504  211100  Police Department  Police Commissioner's Office
# 725505  211100  Police Department  Police Commissioner's Office
# 725506  211100  Police Department  Police Commissioner's Office
# 725507  211100  Police Department  Police Commissioner's Office
# 725508  211100  Police Department  Police Commissioner's Office
# 725509  211100  Police Department  Police Commissioner's Office
# 738131  211100  Police Department  Police Commissioner's Office
# 750096  211705  Police Department        INVESTIGATIVE SERVICES
# 823057  211206  Police Department          TELECOM. MGMT. GROUP
# 834936  211206  Police Department          TELECOM. MGMT. GROUP
# 915666  211705  Police Department        INVESTIGATIVE SERVICES
# 916137  211100  Police Department  Police Commissioner's Office
#
#         monetary_amount              vendor_lower
# 72365           4499.00      cellebrite usa,corp.
# 72366             85.00      cellebrite usa,corp.
# 72369             65.00      cellebrite usa,corp.
# 72370           3999.99      cellebrite usa,corp.
# 72372            416.25      cellebrite usa,corp.
# 72373             35.00      cellebrite usa,corp.
# 72374           2199.00      cellebrite usa,corp.
# 72376           1999.00      cellebrite usa,corp.
# 72377           1099.00      cellebrite usa,corp.
# 72378           4990.00      cellebrite usa,corp.
# 131990           106.00      federal signal corp.
# 131991           606.00      federal signal corp.
# 131992           108.00      federal signal corp.
# 131993            52.00      federal signal corp.
# 167638           200.00         guidance software
# 167639            75.00         guidance software
# 169904          4000.00  harris corporation, gcsd
# 169905         18100.00  harris corporation, gcsd
# 169906          4000.00  harris corporation, gcsd
# 169907         18100.00  harris corporation, gcsd
# 169908         10486.00  harris corporation, gcsd
# 169909         18054.00  harris corporation, gcsd
# 169910         27200.00  harris corporation, gcsd
# 169911         34400.00  harris corporation, gcsd
# 169912         20000.00  harris corporation, gcsd
# 169913         22000.00  harris corporation, gcsd
# 169914         22000.00  harris corporation, gcsd
# 169915         18419.00  harris corporation, gcsd
# 169916         18419.00  harris corporation, gcsd
# 169917         16915.00  harris corporation, gcsd
# ...                 ...                       ...
# 589976           499.00       paraben corporation
# 645010          6700.00           geofeedia, inc.
# 701449           100.00      federal signal corp.
# 701450          1562.82      federal signal corp.
# 725490          8437.73             pen link ltd.
# 725491         10607.80             pen link ltd.
# 725492          3358.75             pen link ltd.
# 725493          1554.91             pen link ltd.
# 725494            92.49             pen link ltd.
# 725495           787.99             pen link ltd.
# 725496          1340.60             pen link ltd.
# 725497            37.30             pen link ltd.
# 725498          1091.93             pen link ltd.
# 725499           497.50             pen link ltd.
# 725500          1962.05             pen link ltd.
# 725501           245.10             pen link ltd.
# 725502         19457.60             pen link ltd.
# 725503           354.49             pen link ltd.
# 725504         15755.00             pen link ltd.
# 725505           502.00             pen link ltd.
# 725506          1327.97             pen link ltd.
# 725507         10000.00             pen link ltd.
# 725508           315.18             pen link ltd.
# 725509         11000.00             pen link ltd.
# 738131          3299.00      cellebrite usa,corp.
# 750096         25500.00             pen link ltd.
# 823057           983.42      federal signal corp.
# 834936           983.42      federal signal corp.
# 915666         25500.00             pen link ltd.
# 916137          3240.00  harris corporation, gcsd
#
# [94 rows x 17 columns]
